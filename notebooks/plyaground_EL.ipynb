# %% [markdown]
# # Download the data from G-drive'

# %%
# import gdown

# # Google Drive folder ID extracted from the URL
# folder_id = "1Z150S8gpXVZZutEBlV0z3ZMxiwD7jZVV"
# gdown.download_folder(f"https://drive.google.com/drive/folders/{folder_id}", quiet=False, use_cookies=False)
# Out:
# Retrieving folder contents
# Retrieving folder 1XdiUxHnFliJoVZT-dYoAuHgUodTs0Axm Actual_demand_for_the_representative_year
# Processing file 18vE74zjfumc2qIyeEW5rcM72Nw1hqDj1 BA_demand_2015.xlsx
# Processing file 16gTS1DwQ32SeSL8WUPqBNDiZZXGpo0ag RS_demand_2019.csv
# Processing file 1L93YxrszPz48mLq5n7AM0srOgFPDZqAX XK_demand_2023.csv
# Retrieving folder 1loOW17grKBLwfT7Pb1U2vNjONwUuDoCI Representative_years_scripts
# Processing file 1Md6GjacjElpd1goxKC_K4KzMS_pJTim- representative_year_SDP_BA.ipynb
# Processing file 1deLTlZMWiM-9d0aWN24TkhL7qDkefLlE representative_year_SDP_RS.ipynb
# Processing file 1gpneFVXY3VnSepE0wQoMXTG3dtWMUim5 representative_year_SDP_XK.ipynb
# Retrieving folder 1I_dKUAk-Lv3frNaB2qa0jXnCLKJymEoY Specified_Demand_Profile
# Processing file 1T_rKOlYxbCtasyACDbOwvyBOb4QjUvWC euclidean_representative_profile_BA.csv
# Processing file 1lPxc7Nf9rdakHg1RThVlUx26PAOpwm7b euclidean_representative_profile_RS.csv
# ...
